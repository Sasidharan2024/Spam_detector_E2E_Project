# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#extract CSV DataSet.
Data=pd.read_csv('C:/Users/Lavanya udhayakumar/Project/Data Set/spam_sms.csv')

# %%
Data
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
#checking For Columns that are available
Data.columns
# Out:
# Index(['v1', 'v2'], dtype='object')

# %%
#renaming the given columns
Data=Data.rename(columns={'v1':'type','v2':'message'})

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   type     5572 non-null   object
#  1   message  5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
#checking null values
Data.isnull().sum()
# Out:
# type       0
# message    0
# dtype: int64

# %%
#function for categorize the message based on the type spam or ham
check=lambda x:1 if x=='spam' else 0

# %%
#applying the function
Data['category']=Data['type'].apply(check)
Data
# Out:
#       type                                            message  category
# 0      ham  Go until jurong point, crazy.. Available only ...         0
# 1      ham                      Ok lar... Joking wif u oni...         0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3      ham  U dun say so early hor... U c already then say...         0
# 4      ham  Nah I don't think he goes to usf, he lives aro...         0
# ...    ...                                                ...       ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...         1
# 5568   ham              Will Ì_ b going to esplanade fr home?         0
# 5569   ham  Pity, * was in mood for that. So...any other s...         0
# 5570   ham  The guy did some bitching but I acted like i'd...         0
# 5571   ham                         Rofl. Its true to its name         0
#
# [5572 rows x 3 columns]

# %%
#checking the duplicate rows which have same message
Data.duplicated().sum()
# Out:
# 403

# %%
#deleting the duplicated values
Data=Data.drop_duplicates()

# %%
#checking the duplicate rows after deleting
Data.duplicated().sum()
# Out:
# 0

# %%
#checking for number of spam and ham based on 1 and 0.
count=Data['category'].value_counts()
count
# Out:
# category
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
#making a pie chart to visualize the category
plt.pie(count,labels=['Not Spam','Spam'],autopct='%0.3f',textprops={'fontsize':14})
plt.axis('equal')
plt.figure(figsize=(10,10))
plt.show()

# %%
# making a column for number of characters
Data['num_character']=Data['message'].apply(len)
Data.head()
# Out:
# C:\Users\Lavanya udhayakumar\AppData\Local\Temp\ipykernel_17124\3804022372.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['num_character']=Data['message'].apply(len)
#    type                                            message  category  \
# 0   ham  Go until jurong point, crazy.. Available only ...         0
# 1   ham                      Ok lar... Joking wif u oni...         0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3   ham  U dun say so early hor... U c already then say...         0
# 4   ham  Nah I don't think he goes to usf, he lives aro...         0
#
#    num_character
# 0            111
# 1             29
# 2            155
# 3             49
# 4             61

# %%
# import tokenize
import nltk
from nltk.tokenize import word_tokenize
# making the function for counting words as well as sentences
words= lambda x: len(nltk.word_tokenize(x))
sentence= lambda x: len(nltk.sent_tokenize(x))

# %%
# making a column for number of words
Data['num_words']=Data['message'].apply(words)
Data.head()
# Out:
# C:\Users\Lavanya udhayakumar\AppData\Local\Temp\ipykernel_17124\3776496314.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['num_words']=Data['message'].apply(words)
#    type                                            message  category  \
# 0   ham  Go until jurong point, crazy.. Available only ...         0
# 1   ham                      Ok lar... Joking wif u oni...         0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3   ham  U dun say so early hor... U c already then say...         0
# 4   ham  Nah I don't think he goes to usf, he lives aro...         0
#
#    num_character  num_words
# 0            111         24
# 1             29          8
# 2            155         37
# ...

# %%
# making a column for number of sentences
Data['num_sentence']=Data['message'].apply(sentence)
Data.head()
# Out:
# C:\Users\Lavanya udhayakumar\AppData\Local\Temp\ipykernel_17124\1844032164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['num_sentence']=Data['message'].apply(sentence)
#    type                                            message  category  \
# 0   ham  Go until jurong point, crazy.. Available only ...         0
# 1   ham                      Ok lar... Joking wif u oni...         0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3   ham  U dun say so early hor... U c already then say...         0
# 4   ham  Nah I don't think he goes to usf, he lives aro...         0
#
#    num_character  num_words  num_sentence
# 0            111         24             2
# 1             29          8             2
# ...

# %%
# categorize the ham message based number of words, sentences and characters
ham=Data[Data['category']==0][['num_character','num_words','num_sentence']]

# %%
ham.describe()
# Out:
#        num_character    num_words  num_sentence
# count    4516.000000  4516.000000   4516.000000
# mean       70.459256    17.123782      1.820195
# std        56.358207    13.493970      1.383657
# min         2.000000     1.000000      1.000000
# 25%        34.000000     8.000000      1.000000
# 50%        52.000000    13.000000      1.000000
# 75%        90.000000    22.000000      2.000000
# max       910.000000   220.000000     38.000000

# %%
# categorize the spam message based number of words, sentences and characters
spam=Data[Data['category']==1][['num_character','num_words','num_sentence']]
spam.head()
# Out:
#     num_character  num_words  num_sentence
# 2             155         37             2
# 5             148         39             4
# 8             158         32             5
# 9             154         31             3
# 11            136         31             3

# %%
spam.describe()
# Out:
#        num_character   num_words  num_sentence
# count     653.000000  653.000000    653.000000
# mean      137.891271   27.667688      2.970904
# std        30.137753    7.008418      1.488425
# min        13.000000    2.000000      1.000000
# 25%       132.000000   25.000000      2.000000
# 50%       149.000000   29.000000      3.000000
# 75%       157.000000   32.000000      4.000000
# max       224.000000   46.000000      9.000000

# %%
# making a histplot for understanding the trend based on the number of characters
sns.histplot(Data[Data['category']==0]['num_character'],color='green')
sns.histplot(Data[Data['category']==1]['num_character'],color='Red')
plt.figure(figsize=(14,8))
# Out:
# C:\Users\Lavanya udhayakumar\DS\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lavanya udhayakumar\DS\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# making a histplot for understanding the trend based on the number of words
sns.histplot(Data[Data['category']==0]['num_words'],color='green')
sns.histplot(Data[Data['category']==1]['num_words'],color='Red')
plt.figure(figsize=(14,8))
# Out:
# C:\Users\Lavanya udhayakumar\DS\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lavanya udhayakumar\DS\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# making a histplot for understanding the trend based on the number of sentences
sns.histplot(Data[Data['category']==0]['num_sentence'],color='green')
sns.histplot(Data[Data['category']==1]['num_sentence'],color='Red')
plt.figure(figsize=(14,8))
# Out:
# C:\Users\Lavanya udhayakumar\DS\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lavanya udhayakumar\DS\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# making the correlation matrix to know the highest correlation between the columns
correlation_matrix=Data[['category','num_character','num_words','num_sentence']].corr()
correlation_matrix
# Out:
#                category  num_character  num_words  num_sentence
# category       1.000000       0.384717   0.262912      0.263939
# num_character  0.384717       1.000000   0.965760      0.624139
# num_words      0.262912       0.965760   1.000000      0.679971
# num_sentence   0.263939       0.624139   0.679971      1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.3f', linewidths=0.5, square=True)
#As we see multicollinearity here, we cannot use all three columns instead we shall use only one 
#and that should be num_characters has it has highest correlation with message_type.
# Out:
# <Axes: >

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# making the function for applying transformation for lowercase , removing the punctuation as well as stopwords.
def transform(message):
#for transform the words to lower case
    message=message.lower()
    message=nltk.word_tokenize(message)
    y=[]
    for i in message:
        if i.isalnum():
           y.append(i)
        y.clear()
#for checking punctuations and stopwords
    for i in message:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    message=y[:]
    y.clear()

#now stemming function
    for i in message:
        y.append(PorterStemmer().stem(i))

    return " ".join(y)

# %%
#creating a column to apply the transformed format of the message.
Data['transform']=Data['message'].apply(transform)
Data
# Out:
# C:\Users\Lavanya udhayakumar\AppData\Local\Temp\ipykernel_17124\485075665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['transform']=Data['message'].apply(transform)
#       type                                            message  category  \
# 0      ham  Go until jurong point, crazy.. Available only ...         0
# 1      ham                      Ok lar... Joking wif u oni...         0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3      ham  U dun say so early hor... U c already then say...         0
# 4      ham  Nah I don't think he goes to usf, he lives aro...         0
# ...    ...                                                ...       ...
# ...

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
#created a word cloud to spam messages for knowing the frequency of the words
spam_wc=wc.generate(Data[Data['category']==1]['transform'].str.cat(sep=""))
plt.figure(figsize=(18,12))
plt.imshow(spam_wc)

# %%
#created a word cloud to ham messages for knowing the frequency of the words
ham_wc=wc.generate(Data[Data['category']==0]['transform'].str.cat(sep=""))
plt.figure(figsize=(18,12))
plt.imshow(ham_wc)

# %%
# collecting the spam words which are important.
spam_corpus=[]
for msg in Data[Data['category']==0]['transform'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
#finding the most important spam words.
from collections import Counter
Counter(spam_corpus).most_common(30)
column_1=pd.DataFrame(Counter(spam_corpus).most_common(30))[0]
column_2=pd.DataFrame(Counter(spam_corpus).most_common(30))[1]

# %%
sns.barplot(x=column_1,y=column_2)
plt.figure(figsize=(18,12))

# %%
# importing sklearn for machine learning
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
tfidf=TfidfVectorizer(max_features=3000)

# %%
# implementing tfidf vectorize to change input columns into vectirize column
X=tfidf.fit_transform(Data['transform']).toarray()
y=Data['category'].values
# applying to split the dataset into train and test dataset. 
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
pie_train =pd.Series(y_train).value_counts()
plt.pie(pie_train, autopct = '%1.1f%%')
plt.ylabel("Spam vs Ham")
plt.xlabel('train data')
plt.legend(["Ham", "Spam"])

# %%
pie_test =pd.Series(y_test).value_counts()
plt.pie(pie_test, autopct = '%1.1f%%')
plt.ylabel("Spam vs Ham")
plt.xlabel('train data')
plt.legend(["Ham", "Spam"])

# %%
#Building a Model using Naive Bayes
#As it is known that on Textual Data Naive Bayes Algorithm works the best hence we will use it but along the way also compare it with different algorithms
#Input is categorical Output is Numerical.
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB 
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score
gnb=GaussianNB() 
bnb=BernoulliNB()
mnb=MultinomialNB()

# %%
gnb.fit(X_train,y_train)
y_pred1= gnb.predict(X_test)
print('Accuracy score of Gaussian NB is: ',accuracy_score(y_test,y_pred1))
print('Confusion Matrix of Guassian NB is: \n',confusion_matrix(y_test,y_pred1))
print('\nPrecision score of the Gaussian NB is',precision_score(y_test,y_pred1))
print('\n',classification_report(y_test, y_pred1))
# Out:
# Accuracy score of Gaussian NB is:  0.8781431334622823
# Confusion Matrix of Guassian NB is:
#  [[790 106]
#  [ 20 118]]
#
# Precision score of the Gaussian NB is 0.5267857142857143
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       896
#            1       0.53      0.86      0.65       138
#
#     accuracy                           0.88      1034
#    macro avg       0.75      0.87      0.79      1034
# weighted avg       0.92      0.88      0.89      1034

# %%
mnb.fit(X_train,y_train)
y_pred2=mnb.predict(X_test)
print('Accuracy score of Multinomial NB is: ',accuracy_score(y_test,y_pred2))
print('Confusion Matrix of Multinomial NB is: \n',confusion_matrix(y_test,y_pred2))
print('\nPrecision score of the Multinomial NB is',precision_score(y_test,y_pred2))
print('\n',classification_report(y_test, y_pred2))
# Out:
# Accuracy score of Multinomial NB is:  0.9748549323017408
# Confusion Matrix of Multinomial NB is:
#  [[896   0]
#  [ 26 112]]
#
# Precision score of the Multinomial NB is 1.0
#
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       896
#            1       1.00      0.81      0.90       138
#
#     accuracy                           0.97      1034
#    macro avg       0.99      0.91      0.94      1034
# weighted avg       0.98      0.97      0.97      1034

# %%
bnb.fit(X_train,y_train)
y_pred3=bnb.predict(X_test)
print('Accuracy score of Bernoulli NB is: ',accuracy_score(y_test,y_pred3))
print('Confusion Matrix of Bernoulli NB is: \n',confusion_matrix(y_test,y_pred3))
print('\nPrecision score of the Bernoulli NB is',precision_score(y_test,y_pred3))
print('\n',classification_report(y_test, y_pred2))
# Out:
# Accuracy score of Bernoulli NB is:  0.988394584139265
# Confusion Matrix of Bernoulli NB is:
#  [[896   0]
#  [ 12 126]]
#
# Precision score of the Bernoulli NB is 1.0
#
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       896
#            1       1.00      0.81      0.90       138
#
#     accuracy                           0.97      1034
#    macro avg       0.99      0.91      0.94      1034
# weighted avg       0.98      0.97      0.97      1034

# %%
# Hence we finalise the Model with MNB(Multinomial Naive Bayes) and TFIDF Vectorization because of its performance.
# we have to save this models using pickle module

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
#2 files will be formed named “model.pkl” and “vectorizer.pkl”.

# %%
#now we building the website using streamlit and file name is spam.py

# %%
#sample check
import pickle

tfidf = pickle.load(open('vectorizer.pkl','rb'))
model = pickle.load(open('model.pkl','rb'))

input_sms = input("Enter the message")

transformed_sms = transform(input_sms)

vector_input = tfidf.transform([transformed_sms])

result = model.predict(vector_input)[0]

if result == 1:
    print("\nSpam")
else:
    print("\nNot Spam")
# Out:
# Enter the message Dear User, You've got ixigo coupon of Upto Rs.5000 OFF on domestic & international flights on My Winnings. Click on https://t.jio/v/r278 to claim. T&C
# Spam

# %%
#message : Dear User, You've got ixigo coupon of Upto Rs.5000 OFF on domestic & international flights on My Winnings. Click on https://t.jio/v/r278 to claim. T&C
